# %% [markdown]
# # Analyse des données de l'article
#
# https://arxiv.org/pdf/2511.16884

# %% [markdown]
# ## Lire de manière brute

# %%
pwd
# Out:
# '/Users/emilien/Dropbox/Python pour les SHS/Formations/2026-01-19 URFIST Paris Python pour les SHS'

# %%
with open("./data/dataverse_files/20251014_combined_survey_responses.csv","r") as fichier:
    data = fichier.read()

# %%
#data

# %% [markdown]
# ## Travailler avec Pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("./data/dataverse_files/20251014_combined_survey_responses.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (433, 73)

# %%
df["english"].value_counts()
# Out:
# english
# True     204
# False    190
# Name: count, dtype: int64

# %%
df["english"].value_counts().plot(kind="bar", title="Language")
# Out:
# <Axes: title={'center': 'Language'}, xlabel='english'>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (3,3))

df["english"].value_counts().plot(kind="bar", title="Language", ax=ax)
plt.ylabel("number")
# Out:
# Text(0, 0.5, 'number')

# %%
df["type"].mean()
# Out:
# np.float64(1.4942263279445727)

# %%
df["type"].var()
# Out:
# 0.25054529124967967

# %%
pd.crosstab(df["gender"], df["english"])
# Out:
# english  False  True
# gender
# False       71     94
# True       119    110

# %%
df[df["english"] == True]
# Out:
#             ResponseId  weight_rake  type  location  gender  white english  \
# 0    R_5s4GSDYAW4TDI90     0.796334     2      True    True   True    True
# 1    R_4HSQnkZNnCbtgOo     2.034334     2     False    True   True    True
# 2    R_3lzzrA0htpPkZmX     0.796334     2      True    True   True    True
# 3    R_7VDdKi1cb9FFRAt     0.796334     2      True    True   True    True
# 6    R_61pGHUC4Ka57Osm     1.284612     2      True   False   True    True
# ..                 ...          ...   ...       ...     ...    ...     ...
# 419  R_6CBB5sPhpDiFnia     0.041674     1      True    True  False    True
# 422  R_3FEfwqhvfLdKtye     0.067226     1      True   False   True    True
# 427  R_3BXlrGa4sK1RNMv     0.106460     1     False    True   True    True
# 430  R_9JUzWlM8PKnEQ4q     0.171737     1     False   False  False    True
# 432  R_3asU9eDWSFlCRdn     0.171737     1     False   False   True    True
#
# ...

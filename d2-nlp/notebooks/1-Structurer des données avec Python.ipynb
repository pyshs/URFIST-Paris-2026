# %% [markdown]
# # Extraire des données de HAL

# %% [markdown]
# Extraire les données

# %%
import requests
import json

rows = 1000
url = "https://api.archives-ouvertes.fr/search/"

params = {
    "q": "collCode_s:CREST",
    "fl": "*",
    "rows": rows,
    "wt": "json"
}

all_docs = []
start = 0

while True:
    params["start"] = start
    params["rows"] = rows

    r = requests.get(url, params=params)
    r.raise_for_status()

    resp = r.json()
    docs = resp["response"]["docs"]

    if not docs:
        break

    all_docs.extend(docs)
    start += rows
    print(f"Fetched {len(docs)} documents, total so far: {len(all_docs)}")

with open("hal_crest_data.json", "w", encoding="utf-8") as f:
    json.dump(all_docs, f, ensure_ascii=False, indent=4)

print(f"Total documents fetched: {len(all_docs)}")
# Out:
# Fetched 1000 documents, total so far: 1000
# Fetched 1000 documents, total so far: 2000
# Fetched 891 documents, total so far: 2891
# Total documents fetched: 2891

# %% [markdown]
# Regarder un document

# %%
#all_docs[0]

# %% [markdown]
# ## Extraire l'information utile
#
# Faire une fonction qui :
# - prend un élément
# - renvoie le titre, l'abstract, la date de publication, le type de document et la liste des auteurs

# %% [markdown]
# Charger le jeu de données

# %%
import json
with open("hal_crest_data.json", "r", encoding = "utf-8") as f:
    data = json.load(f)
len(data)
# Out:
# 2891

# %% [markdown]
# Un élément

# %%
#data[0]

# %% [markdown]
# Définir une fonction pour extraire les données

# %%
def extract_info(doc):
    """
    Extraire les données
    """
    return {
        "docid": doc.get("docid"),
        "title": doc.get("title_s", ""),
        "abstract": doc.get("abstract_s", ""),
        "abstract_eng": doc.get("en_abstract_s", ""),
        "publicationDate_tdate": doc.get("publicationDate_tdate", ""),
        "document_type": doc.get("primaryDomain_s", ""),
        "authors": doc.get("authFullName_s", []),
    }

# %%
# extract_info(data[2])

# %% [markdown]
# Construire le corpus

# %%
corpus = []
for doc in data:
    corpus += [extract_info(doc)]

# %%
len(corpus)
# Out:
# 2891

# %%
import pandas as pd

# extraire les données
corpus = [extract_info(doc) for doc in data]

# mettre sous un format dataframe
df = pd.DataFrame(corpus)
df.set_index("docid", inplace=True)
df.head()
# Out:
#                                                      title  \
# docid
# 3707033  [Unemployment and Online Labor - Evidence from...
# 3026577  [The effect of price magnitude on analysts' fo...
# 4358212  [Model-based Clustering with Missing Not At Ra...
# 5444020  [Stationarity and ergodic properties for some ...
# 4996040  [Inferring the parameters of Taylor’s power la...
#
#                                                   abstract  \
# docid
# 3707033
# 3026577  [Recent research in finance shows that the mag...
# 4358212  [Model-based unsupervised learning, as any lea...
# 5444020
# 4996040  [Taylor’s power law of fluctuation scaling has...
#
#                                               abstract_eng  \
# docid
# 3707033
# 3026577  [Recent research in finance shows that the mag...
# 4358212  [Model-based unsupervised learning, as any lea...
# 5444020
# 4996040  [Taylor’s power law of fluctuation scaling has...
#
#         publicationDate_tdate           document_type  \
# docid
# 3707033  2022-06-13T00:00:00Z                 shs.eco
# 3026577  2021-01-01T00:00:00Z                 shs.eco
# 4358212  2024-06-18T00:00:00Z                 stat.ml
# 5444020  2023-12-01T00:00:00Z  phys.phys.phys-data-an
# 4996040  2025-11-26T00:00:00Z                    stat
#
#                                                    authors
# docid
# 3707033  [Ulrich Laitenberger, Steffen Viete, Olga Sliv...
# 3026577  [Tristan Roger, Wael Bousselmi, Patrick Roger,...
# 4358212  [Aude Sportisse, Matthieu Marbac, Fabien Lapor...
# 5444020  [Paul Doukhan, Lionel Truquet, Michael H. Neum...
# 4996040      [Lionel Truquet, Joel E. Cohen, Paul Doukhan]

# %%
df = pd.DataFrame([extract_info(doc) for doc in data]).set_index("docid")

# %% [markdown]
# Mettre en forme
# - ne garder que les éléments contenant un abstract
# - mettre en forme les dates

# %%
# enlever les lignes sans abstract
df_ss = df[df["abstract"].notna() & (df["abstract"] != "")]

# mettre la date en format date
df_ss["date"] = pd.to_datetime(df_ss["publicationDate_tdate"], errors='coerce').dt.date

# écrire tout dans un fichier excel
df_ss.to_excel("data_hal_crest.xlsx")
df_ss.shape
# Out:
# (2308, 7)
